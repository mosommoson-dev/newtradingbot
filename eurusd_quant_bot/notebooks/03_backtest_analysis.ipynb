# %% [markdown]
# # 03 — Backtest analysis
#
# Walk-forward + Monte-Carlo on the chosen strategy.

# %%
from eurusd_quant_bot.backtest import walk_forward
from eurusd_quant_bot.data import clean_ohlcv, fetch_yfinance
from eurusd_quant_bot.strategy import TrendFollowingStrategy

df = clean_ohlcv(fetch_yfinance(granularity='H1', start='2020-01-01'))
wf = walk_forward(df, TrendFollowingStrategy, n_trials=20)
wf.summary
