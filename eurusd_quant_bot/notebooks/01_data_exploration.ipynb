# %% [markdown]
# # 01 — Data exploration
#
# Quick look at EUR/USD H1 bars from yfinance: gaps, spreads, volatility regimes.

# %%
from eurusd_quant_bot.data import clean_ohlcv, fetch_yfinance

df = clean_ohlcv(fetch_yfinance(granularity='H1', start='2022-01-01'))
df.tail()
